# %% [markdown]
# # Reinforcement Learning for Wordle
#
# ## Problem Statement
# Last week a working collegue showed me Wordle. Since he has been playing Wordle for a long period of time, I thought I could use this project to cheat my way through our games, so that I can beat him in future.
#
# ## So what is Wordle?
#
# Wordle is a word puzzle game where a player has six chances to guess a five-letter word. Only valid words are accepted. After each guess, the player receives feedback:
# - **Green**: The letter is correct and in the right position.
# - **Orange**: The letter is used in the target word but it is in the wrong position.
# - **Gray**: The letter is not in the word at all.
#
# While there are various strategies available online to optimize guessing, there is no definitive approach to consistently solving Wordle efficiently. Most people use words in the beginning that use the most common letters in order to find out
# which letters are used in the target word.
# Common starting words include:
# - **SLATE**
# - **CRANE**
# - **TRACE**
#
#
# However, the best strategy is to adapt based on the feedback received.
#
#
# ## Solution Implementation
# My project aims to develop a **Reinforcement Learning (RL) model** to build an adaptive strategy for solving Wordle puzzles more efficiently and most importantly, faster than my collegue. The RL model will:
# 1. Learn through trial and error.
# 2. Optimize guesses based on past experiences.
# 3. Adjust its strategy dynamically based on the feedback received in each round.
#
# ## How does it work?
#
# The implementation is based on **Deep Q-Learning (DQN)**, where:
# - The **state** represents the current knowledge of the word (correct, misplaced, and incorrect letters). This is then stored in a 6,5 matrix that is updated after each guess.
# - The **action** is choosing a word from a predefined vocabulary, filtered to remove unlikely options based on previous feedback.
# - The **reward** is based on how close the guess is to the correct word—extra points for correct letters in the right spots and a penalty for unnecessary guesses. (Without this penalty guessing 5 times with 4 correct words would result in higher reward then guessing 2 times and then finding the correct word)
#
# The code uses **PyTorch** for neural network training and **a custom Gym Enviroment** to simulate a Wordle game.
#
# ## How can you use it?
# To run the model, you need to have the following files and dependencies in place:
#
# ### Required Files:
# 1. `wordle_env.py` - Implements the Wordle game environment in a format compatible with reinforcement learning.
# 2. `dqn_model.py` - Contains the DQN architecture for decision-making.
# 3. `train.py` - The main training script that runs episodes and updates the model.
# 4. `word_list.txt` - A list of possible words that can be used for training and evaluation.
#
# ### Installation:
# Ensure you have the required dependencies installed:
# ```bash
# pip install torch numpy gym
# ```
#
# ### Running the Model:
# To train the reinforcement learning model, execute:
# ```bash
# python train.py
# ```
# This will run multiple training episodes, and thus refine the model´s guessing strategy, Once it is trained it is saved then as  `wordle_dqn_model_optimized.pth`.
#
# ## Conclusion
# This project explored how reinforcement learning can be applied to solve Wordle in a smarter Way. By learning from experience and adjusting dynamically, the model aims to perform better than traditional word guessing strategies - and most importantly then me who is still trying to learn how to play this in the best way.

# %%
# First I looked online for a valid word list for Wordle. I then scraped the results and saved them in a file. My program should use words from this list as targets and use the list to filter the outcome.
url = "https://gist.githubusercontent.com/cfreshman/a03ef2cba789d8cf00c08f767e0fad7b/raw/45c977427419a1e0edee8fd395af1e0a4966273b/wordle-answers-alphabetical.txt"
response = requests.get(url)
response.raise_for_status()
word_list = [word.strip().lower() for word in response.text.split("\n") if len(word) == 5]

with open("wordle_words.txt", "w", encoding="utf-8") as file:
    file.write("\n".join(word_list))

# %% [markdown]
# This is the best Version I got until now.

# %%
import requests
import random
import numpy as np
import gym
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import torch.nn.functional as F

# First I define starting words that contain the most frequently used letters (according to the best Wordle startegy online)
START_WORDS = ["slate", "crane", "trace"]

# Then I define the Wordle environment
class WordletwoEnv(gym.Env):
    def __init__(self, word_list):
        super(WordletwoEnv, self).__init__()
        self.word_list = word_list
        
        self.action_space = gym.spaces.Discrete(len(self.word_list))
        self.observation_space = gym.spaces.Box(low=0, high=2, shape=(6, 5), dtype=np.int8)
        self.history = np.zeros((6, 5), dtype=np.int8)
        
        self.green_letters = [''] * 5
        self.yellow_letters = {}
        self.gray_letters = set()
        
        self.reset()
    
    def reset(self):
        self.target_word = random.choice(self.word_list)
        self.attempts = 0
        self.done = False
        self.history.fill(0)
        self.green_letters = [''] * 5
        self.yellow_letters.clear()
        self.gray_letters.clear()
    
        return self.history

    def filter_valid_words(self):
        valid_words = []
        for word in self.word_list:
            valid = True

            # Check green letters
            for i, letter in enumerate(self.green_letters):
                if letter and word[i] != letter:
                    valid = False
                    break

            # Check gray letters
            if any(letter in word for letter in self.gray_letters):
                valid = False
            
            # Check yellow letters
            for letter, positions in self.yellow_letters.items():
                if letter not in word:
                    valid = False
                    break
                if any(word[pos] == letter for pos in positions):
                    valid = False
                    break

            if valid:
                valid_words.append(word)

        return valid_words if valid_words else self.word_list  # Fallback if no valid words left

    def best_guess(self, valid_words):
        return max(valid_words, key=lambda w: len(set(w) - self.gray_letters))
    
    def step(self, action):
        if self.done:
            return self.history, 0, self.done, {}

        valid_words = self.filter_valid_words()
        if len(valid_words) == 0:
            valid_words = self.word_list  # Fallback selection

        guess_word = self.best_guess(valid_words)

        feedback = self._get_feedback(guess_word)
        self.history[self.attempts] = feedback
        self.attempts += 1

        reward = self._calculate_reward(feedback, guess_word)

        if guess_word == self.target_word:
            reward += 100
            self.done = True

        if self.attempts >= 6:
            self.done = True

        return self.history, reward, self.done, {"word_guessed": guess_word == self.target_word, "attempts": self.attempts}

    def _calculate_reward(self, feedback, guess_word):
        reward = np.count_nonzero(feedback == 2) * 10  # Higher reward for correct letters (in Wordle green)
        reward += np.count_nonzero(feedback == 1) * 5  # Moderate reward for correct letters in wrong position (in Wordle yellow)
        reward -= 1  # Small penalty for each guess to encourage efficiency (in previous models the reward system did not work because guessing the word correctly after 2 times did get less rewards then guessing 5 times 4 correct letters and then finding the correct word)
        return reward
   ## This reward stucture gave me worse results
   # def _calculate_reward(self, feedback, guess_word):
        reward = np.count_nonzero(feedback == 2) * 10  # 10 points per correct letter (green)
        reward += np.count_nonzero(feedback == 1) * 5  # 5 points per misplaced letter (yellow)
        
        # BIG Reward for finding the correct word, decreasing with attempts
        if guess_word == self.target_word:
            reward += 500 - (self.attempts * 20)  # Large base reward, decreasing per attempt
            self.done = True

        # Penalty per guess to encourage efficiency
        reward -= self.attempts * 5  # Increasing penalty the more attempts are used
    
        return reward


    def _get_feedback(self, guess):
        feedback = np.zeros(5, dtype=np.int8)
        target_word_list = list(self.target_word)
        
        for i, letter in enumerate(guess):
            if letter == self.target_word[i]:
                feedback[i] = 2
                self.green_letters[i] = letter
                target_word_list[i] = None
        
        for i, letter in enumerate(guess):
            if feedback[i] == 0 and letter in target_word_list:
                feedback[i] = 1
                if letter not in self.yellow_letters:
                    self.yellow_letters[letter] = set()
                self.yellow_letters[letter].add(i)
                target_word_list[target_word_list.index(letter)] = None
            elif feedback[i] == 0:
                self.gray_letters.add(letter)
        
        return feedback
    def test_step(self, action):
        """ Step function for testing. Prints attempts for understanding. """
        if self.done:
            return self.history, 0, self.done, {}

        valid_words = self.filter_valid_words()
        if len(valid_words) == 0:
            print("No valid words left! Using fallback selection.")
            valid_words = self.word_list

        # Select the best guess
        guess_word = self.best_guess(valid_words)

        feedback = self._get_feedback(guess_word)

        # Print output to understanding how it works and thus debugging
        print(f"Attempt {self.attempts + 1}: {guess_word.upper()}")
        print("Feedback:", " ".join(["🟩" if x == 2 else "🟨" if x == 1 else "⬜" for x in feedback]))

        self.history[self.attempts] = feedback
        self.attempts += 1

        reward = np.count_nonzero(feedback == 2) * 5
        reward += np.count_nonzero(feedback == 1) * 2

        if guess_word == self.target_word:
            print(f"Correct word found in {self.attempts} attempts! 🎉")
            reward += 100
            self.done = True

        if self.attempts >= 6:
            print("Maximum attempts reached. Moving to next episode.")
            self.done = True

        return self.history, reward, self.done, {"word_guessed": guess_word == self.target_word, "attempts": self.attempts}

# Now I define the neural network
class WordleDQN(nn.Module):
    def __init__(self, input_shape, num_actions):
        super(WordleDQN, self).__init__()
        self.fc1 = nn.Linear(input_shape, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, num_actions)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten the input tensor
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

import pandas as pd
def train(env, model, optimizer, episodes=1000, gamma=0.99, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.995):
    memory = deque(maxlen=10000)
    batch_size = 64
    rewards_list = []  
    epsilon_list = []  
    episode_list = []  
    attempts_list = []  # Stores attempts per episode
    success_list = []   # Stores whether the episode was successful (Step was needed because previously I could not understand the reward structure, as in a previous program there was a bug, no episode was successfull but all had high rewards)

    for episode in range(episodes):
        state = env.reset()
        total_reward = 0
        done = False

        while not done:
            if random.random() < epsilon:
                action = env.action_space.sample()
            else:
                state_tensor = torch.FloatTensor(state).unsqueeze(0)
                q_values = model(state_tensor)
                action = torch.argmax(q_values).item()

            next_state, reward, done, info = env.step(action)
            memory.append((state, action, reward, next_state, done))
            state = next_state
            total_reward += reward

            if len(memory) > batch_size:
                minibatch = random.sample(memory, batch_size)
                states, actions, rewards, next_states, dones = zip(*minibatch)

                states = torch.FloatTensor(np.array(states))
                actions = torch.LongTensor(actions)
                rewards = torch.FloatTensor(rewards)
                next_states = torch.FloatTensor(np.array(next_states))
                dones = torch.FloatTensor(dones)

                current_q = model(states).gather(1, actions.unsqueeze(1))
                next_q = model(next_states).max(1)[0].detach()
                target_q = rewards + (gamma * next_q * (1 - dones))

                loss = F.mse_loss(current_q.squeeze(), target_q)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        epsilon = max(epsilon_min, epsilon * epsilon_decay)

        # Store episode data
        rewards_list.append(total_reward)
        epsilon_list.append(epsilon)
        episode_list.append(episode + 1)
        attempts_list.append(env.attempts)  # Track number of attempts
        success_list.append(int(info["word_guessed"]))  # 1 if successful, 0 otherwise

        print(f"Episode {episode + 1}, Total Reward: {total_reward}, Attempts: {env.attempts}, Success: {info['word_guessed']}, Epsilon: {epsilon:.5f}")

    # Then I save results to a CSV file in order to be able to analyse them later 
    results_df = pd.DataFrame({
        "Episode": episode_list,
        "Total Reward": rewards_list,
        "Attempts": attempts_list,
        "Success": success_list,
        "Epsilon": epsilon_list
    })
    results_df.to_csv("wordletwo_rl_results.csv", index=False)

    return rewards_list

# Initialize environment and model
env = WordletwoEnv(word_list)
model = WordleDQN(env.observation_space.shape[0] * env.observation_space.shape[1], env.action_space.n)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train the model
rewards = train(env, model, optimizer)
# Out:
# Episode 1, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.99500
# Episode 2, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.99003
# Episode 3, Total Reward: 226, Attempts: 4, Success: True, Epsilon: 0.98507
# Episode 4, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.98015
# Episode 5, Total Reward: 156, Attempts: 4, Success: True, Epsilon: 0.97525
# Episode 6, Total Reward: 234, Attempts: 6, Success: True, Epsilon: 0.97037
# Episode 7, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.96552
# Episode 8, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.96069
# Episode 9, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.95589
# Episode 10, Total Reward: 226, Attempts: 4, Success: True, Epsilon: 0.95111
# Episode 11, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.94635
# Episode 12, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.94162
# Episode 13, Total Reward: 157, Attempts: 3, Success: True, Epsilon: 0.93691
# Episode 14, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.93223
# Episode 15, Total Reward: 157, Attempts: 3, Success: True, Epsilon: 0.92757
# Episode 16, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.92293
# Episode 17, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.91832
# Episode 18, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.91372
# Episode 19, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.90916
# Episode 20, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.90461
# Episode 21, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.90009
# Episode 22, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.89559
# Episode 23, Total Reward: 152, Attempts: 3, Success: True, Epsilon: 0.89111
# Episode 24, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.88665
# Episode 25, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.88222
# Episode 26, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.87781
# Episode 27, Total Reward: 157, Attempts: 3, Success: True, Epsilon: 0.87342
# Episode 28, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.86905
# Episode 29, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.86471
# Episode 30, Total Reward: 250, Attempts: 5, Success: True, Epsilon: 0.86038
# Episode 31, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.85608
# Episode 32, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.85180
# Episode 33, Total Reward: 189, Attempts: 6, Success: False, Epsilon: 0.84754
# Episode 34, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.84331
# Episode 35, Total Reward: 240, Attempts: 5, Success: True, Epsilon: 0.83909
# Episode 36, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.83489
# Episode 37, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.83072
# Episode 38, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.82657
# Episode 39, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.82243
# Episode 40, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.81832
# Episode 41, Total Reward: 254, Attempts: 6, Success: True, Epsilon: 0.81423
# Episode 42, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.81016
# Episode 43, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.80611
# Episode 44, Total Reward: 207, Attempts: 3, Success: True, Epsilon: 0.80208
# Episode 45, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.79807
# Episode 46, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.79408
# Episode 47, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.79010
# Episode 48, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.78615
# Episode 49, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.78222
# Episode 50, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.77831
# Episode 51, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.77442
# Episode 52, Total Reward: 231, Attempts: 4, Success: True, Epsilon: 0.77055
# Episode 53, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.76670
# Episode 54, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.76286
# Episode 55, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.75905
# Episode 56, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.75525
# Episode 57, Total Reward: 245, Attempts: 5, Success: True, Epsilon: 0.75148
# Episode 58, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.74772
# Episode 59, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.74398
# Episode 60, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.74026
# Episode 61, Total Reward: 249, Attempts: 6, Success: True, Epsilon: 0.73656
# Episode 62, Total Reward: 260, Attempts: 5, Success: True, Epsilon: 0.73288
# Episode 63, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.72921
# Episode 64, Total Reward: 200, Attempts: 5, Success: True, Epsilon: 0.72557
# Episode 65, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.72194
# Episode 66, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.71833
# Episode 67, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.71474
# Episode 68, Total Reward: 161, Attempts: 4, Success: True, Epsilon: 0.71116
# Episode 69, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.70761
# Episode 70, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.70407
# Episode 71, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.70055
# Episode 72, Total Reward: 168, Attempts: 2, Success: True, Epsilon: 0.69705
# Episode 73, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.69356
# Episode 74, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.69009
# Episode 75, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.68664
# Episode 76, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.68321
# Episode 77, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.67979
# Episode 78, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.67639
# Episode 79, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.67301
# Episode 80, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.66965
# Episode 81, Total Reward: 249, Attempts: 6, Success: True, Epsilon: 0.66630
# Episode 82, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.66297
# Episode 83, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.65965
# Episode 84, Total Reward: 245, Attempts: 5, Success: True, Epsilon: 0.65635
# Episode 85, Total Reward: 178, Attempts: 2, Success: True, Epsilon: 0.65307
# Episode 86, Total Reward: 200, Attempts: 5, Success: True, Epsilon: 0.64981
# Episode 87, Total Reward: 235, Attempts: 5, Success: True, Epsilon: 0.64656
# Episode 88, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.64333
# Episode 89, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.64011
# Episode 90, Total Reward: 229, Attempts: 6, Success: True, Epsilon: 0.63691
# Episode 91, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.63372
# Episode 92, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.63056
# Episode 93, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.62740
# Episode 94, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.62427
# Episode 95, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.62114
# Episode 96, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.61804
# Episode 97, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.61495
# Episode 98, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.61187
# Episode 99, Total Reward: 207, Attempts: 3, Success: True, Epsilon: 0.60881
# Episode 100, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.60577
# Episode 101, Total Reward: 234, Attempts: 6, Success: True, Epsilon: 0.60274
# Episode 102, Total Reward: 255, Attempts: 5, Success: True, Epsilon: 0.59973
# Episode 103, Total Reward: 229, Attempts: 6, Success: True, Epsilon: 0.59673
# Episode 104, Total Reward: 190, Attempts: 5, Success: True, Epsilon: 0.59375
# Episode 105, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.59078
# Episode 106, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.58782
# Episode 107, Total Reward: 250, Attempts: 5, Success: True, Epsilon: 0.58488
# Episode 108, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.58196
# Episode 109, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.57905
# Episode 110, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.57615
# Episode 111, Total Reward: 185, Attempts: 5, Success: True, Epsilon: 0.57327
# Episode 112, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.57041
# Episode 113, Total Reward: 200, Attempts: 5, Success: True, Epsilon: 0.56756
# Episode 114, Total Reward: 202, Attempts: 3, Success: True, Epsilon: 0.56472
# Episode 115, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.56189
# Episode 116, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.55908
# Episode 117, Total Reward: 226, Attempts: 4, Success: True, Epsilon: 0.55629
# Episode 118, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.55351
# Episode 119, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.55074
# Episode 120, Total Reward: 265, Attempts: 5, Success: True, Epsilon: 0.54799
# Episode 121, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.54525
# Episode 122, Total Reward: 205, Attempts: 5, Success: True, Epsilon: 0.54252
# Episode 123, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.53981
# Episode 124, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.53711
# Episode 125, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.53442
# Episode 126, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.53175
# Episode 127, Total Reward: 240, Attempts: 5, Success: True, Epsilon: 0.52909
# Episode 128, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.52645
# Episode 129, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.52381
# Episode 130, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.52120
# Episode 131, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.51859
# Episode 132, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.51600
# Episode 133, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.51342
# Episode 134, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.51085
# Episode 135, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.50830
# Episode 136, Total Reward: 245, Attempts: 5, Success: True, Epsilon: 0.50575
# Episode 137, Total Reward: 207, Attempts: 3, Success: True, Epsilon: 0.50322
# Episode 138, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.50071
# Episode 139, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.49821
# Episode 140, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.49571
# Episode 141, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.49324
# Episode 142, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.49077
# Episode 143, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.48832
# Episode 144, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.48587
# Episode 145, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.48344
# Episode 146, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.48103
# Episode 147, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.47862
# Episode 148, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.47623
# Episode 149, Total Reward: 205, Attempts: 5, Success: True, Epsilon: 0.47385
# Episode 150, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.47148
# Episode 151, Total Reward: 185, Attempts: 5, Success: True, Epsilon: 0.46912
# Episode 152, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.46678
# Episode 153, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.46444
# Episode 154, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.46212
# Episode 155, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.45981
# Episode 156, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.45751
# Episode 157, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.45522
# Episode 158, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.45295
# Episode 159, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.45068
# Episode 160, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.44843
# Episode 161, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.44619
# Episode 162, Total Reward: 231, Attempts: 4, Success: True, Epsilon: 0.44396
# Episode 163, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.44174
# Episode 164, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.43953
# Episode 165, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.43733
# Episode 166, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.43514
# Episode 167, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.43297
# Episode 168, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.43080
# Episode 169, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.42865
# Episode 170, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.42650
# Episode 171, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.42437
# Episode 172, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.42225
# Episode 173, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.42014
# Episode 174, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.41804
# Episode 175, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.41595
# Episode 176, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.41387
# Episode 177, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.41180
# Episode 178, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.40974
# Episode 179, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.40769
# Episode 180, Total Reward: 151, Attempts: 4, Success: True, Epsilon: 0.40565
# Episode 181, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.40362
# Episode 182, Total Reward: 236, Attempts: 4, Success: True, Epsilon: 0.40161
# Episode 183, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.39960
# Episode 184, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.39760
# Episode 185, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.39561
# Episode 186, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.39363
# Episode 187, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.39167
# Episode 188, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.38971
# Episode 189, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.38776
# Episode 190, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.38582
# Episode 191, Total Reward: 280, Attempts: 5, Success: True, Epsilon: 0.38389
# Episode 192, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.38197
# Episode 193, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.38006
# Episode 194, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.37816
# Episode 195, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.37627
# Episode 196, Total Reward: 169, Attempts: 6, Success: False, Epsilon: 0.37439
# Episode 197, Total Reward: 169, Attempts: 6, Success: False, Epsilon: 0.37252
# Episode 198, Total Reward: 259, Attempts: 6, Success: True, Epsilon: 0.37066
# Episode 199, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.36880
# Episode 200, Total Reward: 144, Attempts: 6, Success: False, Epsilon: 0.36696
# Episode 201, Total Reward: 161, Attempts: 4, Success: True, Epsilon: 0.36512
# Episode 202, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.36330
# Episode 203, Total Reward: 240, Attempts: 5, Success: True, Epsilon: 0.36148
# Episode 204, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.35967
# Episode 205, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.35788
# Episode 206, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.35609
# Episode 207, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.35431
# Episode 208, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.35253
# Episode 209, Total Reward: 234, Attempts: 6, Success: True, Epsilon: 0.35077
# Episode 210, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.34902
# Episode 211, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.34727
# Episode 212, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.34554
# Episode 213, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.34381
# Episode 214, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.34209
# Episode 215, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.34038
# Episode 216, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.33868
# Episode 217, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.33698
# Episode 218, Total Reward: 207, Attempts: 3, Success: True, Epsilon: 0.33530
# Episode 219, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.33362
# Episode 220, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.33195
# Episode 221, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.33029
# Episode 222, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.32864
# Episode 223, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.32700
# Episode 224, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.32536
# Episode 225, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.32374
# Episode 226, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.32212
# Episode 227, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.32051
# Episode 228, Total Reward: 231, Attempts: 4, Success: True, Epsilon: 0.31891
# Episode 229, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.31731
# Episode 230, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.31572
# Episode 231, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.31415
# Episode 232, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.31258
# Episode 233, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.31101
# Episode 234, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.30946
# Episode 235, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.30791
# Episode 236, Total Reward: 209, Attempts: 6, Success: True, Epsilon: 0.30637
# Episode 237, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.30484
# Episode 238, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.30331
# Episode 239, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.30180
# Episode 240, Total Reward: 250, Attempts: 5, Success: True, Epsilon: 0.30029
# Episode 241, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.29879
# Episode 242, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.29729
# Episode 243, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.29581
# Episode 244, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.29433
# Episode 245, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.29286
# Episode 246, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.29139
# Episode 247, Total Reward: 250, Attempts: 5, Success: True, Epsilon: 0.28994
# Episode 248, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.28849
# Episode 249, Total Reward: 255, Attempts: 5, Success: True, Epsilon: 0.28704
# Episode 250, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.28561
# Episode 251, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.28418
# Episode 252, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.28276
# Episode 253, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.28135
# Episode 254, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.27994
# Episode 255, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.27854
# Episode 256, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.27715
# Episode 257, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.27576
# Episode 258, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.27438
# Episode 259, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.27301
# Episode 260, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.27164
# Episode 261, Total Reward: 174, Attempts: 6, Success: False, Epsilon: 0.27029
# Episode 262, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.26893
# Episode 263, Total Reward: 79, Attempts: 6, Success: False, Epsilon: 0.26759
# Episode 264, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.26625
# Episode 265, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.26492
# Episode 266, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.26360
# Episode 267, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.26228
# Episode 268, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.26097
# Episode 269, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.25966
# Episode 270, Total Reward: 264, Attempts: 6, Success: True, Epsilon: 0.25836
# Episode 271, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.25707
# Episode 272, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.25579
# Episode 273, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.25451
# Episode 274, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.25324
# Episode 275, Total Reward: 195, Attempts: 5, Success: True, Epsilon: 0.25197
# Episode 276, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.25071
# Episode 277, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.24946
# Episode 278, Total Reward: 185, Attempts: 5, Success: True, Epsilon: 0.24821
# Episode 279, Total Reward: 190, Attempts: 5, Success: True, Epsilon: 0.24697
# Episode 280, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.24573
# Episode 281, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.24450
# Episode 282, Total Reward: 156, Attempts: 4, Success: True, Epsilon: 0.24328
# Episode 283, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.24206
# Episode 284, Total Reward: 265, Attempts: 5, Success: True, Epsilon: 0.24085
# Episode 285, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.23965
# Episode 286, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.23845
# Episode 287, Total Reward: 304, Attempts: 6, Success: True, Epsilon: 0.23726
# Episode 288, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.23607
# Episode 289, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.23489
# Episode 290, Total Reward: 174, Attempts: 6, Success: False, Epsilon: 0.23372
# Episode 291, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.23255
# Episode 292, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.23139
# Episode 293, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.23023
# Episode 294, Total Reward: 153, Attempts: 2, Success: True, Epsilon: 0.22908
# Episode 295, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.22793
# Episode 296, Total Reward: 270, Attempts: 5, Success: True, Epsilon: 0.22679
# Episode 297, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.22566
# Episode 298, Total Reward: 224, Attempts: 6, Success: True, Epsilon: 0.22453
# Episode 299, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.22341
# Episode 300, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.22229
# Episode 301, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.22118
# Episode 302, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.22007
# Episode 303, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.21897
# Episode 304, Total Reward: 164, Attempts: 6, Success: False, Epsilon: 0.21788
# Episode 305, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.21679
# Episode 306, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.21571
# Episode 307, Total Reward: 274, Attempts: 6, Success: True, Epsilon: 0.21463
# Episode 308, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.21355
# Episode 309, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.21249
# Episode 310, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.21142
# Episode 311, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.21037
# Episode 312, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.20932
# Episode 313, Total Reward: 240, Attempts: 5, Success: True, Epsilon: 0.20827
# Episode 314, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.20723
# Episode 315, Total Reward: 260, Attempts: 5, Success: True, Epsilon: 0.20619
# Episode 316, Total Reward: 190, Attempts: 5, Success: True, Epsilon: 0.20516
# Episode 317, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.20413
# Episode 318, Total Reward: 250, Attempts: 5, Success: True, Epsilon: 0.20311
# Episode 319, Total Reward: 245, Attempts: 5, Success: True, Epsilon: 0.20210
# Episode 320, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.20109
# Episode 321, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.20008
# Episode 322, Total Reward: 173, Attempts: 2, Success: True, Epsilon: 0.19908
# Episode 323, Total Reward: 159, Attempts: 6, Success: False, Epsilon: 0.19809
# Episode 324, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.19710
# Episode 325, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.19611
# Episode 326, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.19513
# Episode 327, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.19415
# Episode 328, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.19318
# Episode 329, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.19222
# Episode 330, Total Reward: 265, Attempts: 5, Success: True, Epsilon: 0.19126
# Episode 331, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.19030
# Episode 332, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.18935
# Episode 333, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.18840
# Episode 334, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.18746
# Episode 335, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.18652
# Episode 336, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.18559
# Episode 337, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.18466
# Episode 338, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.18374
# Episode 339, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.18282
# Episode 340, Total Reward: 250, Attempts: 5, Success: True, Epsilon: 0.18191
# Episode 341, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.18100
# Episode 342, Total Reward: 202, Attempts: 3, Success: True, Epsilon: 0.18009
# Episode 343, Total Reward: 245, Attempts: 5, Success: True, Epsilon: 0.17919
# Episode 344, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.17830
# Episode 345, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.17740
# Episode 346, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.17652
# Episode 347, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.17563
# Episode 348, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.17476
# Episode 349, Total Reward: 229, Attempts: 6, Success: True, Epsilon: 0.17388
# Episode 350, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.17301
# Episode 351, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.17215
# Episode 352, Total Reward: 158, Attempts: 2, Success: True, Epsilon: 0.17129
# Episode 353, Total Reward: 190, Attempts: 5, Success: True, Epsilon: 0.17043
# Episode 354, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.16958
# Episode 355, Total Reward: 190, Attempts: 5, Success: True, Epsilon: 0.16873
# Episode 356, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.16789
# Episode 357, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.16705
# Episode 358, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.16621
# Episode 359, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.16538
# Episode 360, Total Reward: 190, Attempts: 5, Success: True, Epsilon: 0.16455
# Episode 361, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.16373
# Episode 362, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.16291
# Episode 363, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.16210
# Episode 364, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.16129
# Episode 365, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.16048
# Episode 366, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.15968
# Episode 367, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.15888
# Episode 368, Total Reward: 168, Attempts: 2, Success: True, Epsilon: 0.15809
# Episode 369, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.15730
# Episode 370, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.15651
# Episode 371, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.15573
# Episode 372, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.15495
# Episode 373, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.15417
# Episode 374, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.15340
# Episode 375, Total Reward: 245, Attempts: 5, Success: True, Epsilon: 0.15264
# Episode 376, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.15187
# Episode 377, Total Reward: 205, Attempts: 5, Success: True, Epsilon: 0.15111
# Episode 378, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.15036
# Episode 379, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.14961
# Episode 380, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.14886
# Episode 381, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.14811
# Episode 382, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.14737
# Episode 383, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.14664
# Episode 384, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.14590
# Episode 385, Total Reward: 202, Attempts: 3, Success: True, Epsilon: 0.14517
# Episode 386, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.14445
# Episode 387, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.14372
# Episode 388, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.14301
# Episode 389, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.14229
# Episode 390, Total Reward: 185, Attempts: 5, Success: True, Epsilon: 0.14158
# Episode 391, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.14087
# Episode 392, Total Reward: 202, Attempts: 3, Success: True, Epsilon: 0.14017
# Episode 393, Total Reward: 195, Attempts: 5, Success: True, Epsilon: 0.13947
# Episode 394, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.13877
# Episode 395, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.13808
# Episode 396, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.13739
# Episode 397, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.13670
# Episode 398, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.13601
# Episode 399, Total Reward: 205, Attempts: 5, Success: True, Epsilon: 0.13533
# Episode 400, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.13466
# Episode 401, Total Reward: 157, Attempts: 3, Success: True, Epsilon: 0.13398
# Episode 402, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.13331
# Episode 403, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.13265
# Episode 404, Total Reward: 69, Attempts: 6, Success: False, Epsilon: 0.13199
# Episode 405, Total Reward: 226, Attempts: 4, Success: True, Epsilon: 0.13133
# Episode 406, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.13067
# Episode 407, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.13002
# Episode 408, Total Reward: 259, Attempts: 6, Success: True, Epsilon: 0.12937
# Episode 409, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.12872
# Episode 410, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.12807
# Episode 411, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.12743
# Episode 412, Total Reward: 240, Attempts: 5, Success: True, Epsilon: 0.12680
# Episode 413, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.12616
# Episode 414, Total Reward: 226, Attempts: 4, Success: True, Epsilon: 0.12553
# Episode 415, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.12490
# Episode 416, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.12428
# Episode 417, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.12366
# Episode 418, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.12304
# Episode 419, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.12243
# Episode 420, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.12181
# Episode 421, Total Reward: 190, Attempts: 5, Success: True, Epsilon: 0.12120
# Episode 422, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.12060
# Episode 423, Total Reward: 289, Attempts: 6, Success: True, Epsilon: 0.12000
# Episode 424, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.11940
# Episode 425, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.11880
# Episode 426, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.11820
# Episode 427, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.11761
# Episode 428, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.11702
# Episode 429, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.11644
# Episode 430, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.11586
# Episode 431, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.11528
# Episode 432, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.11470
# Episode 433, Total Reward: 207, Attempts: 3, Success: True, Epsilon: 0.11413
# Episode 434, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.11356
# Episode 435, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.11299
# Episode 436, Total Reward: 185, Attempts: 5, Success: True, Epsilon: 0.11243
# Episode 437, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.11186
# Episode 438, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.11130
# Episode 439, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.11075
# Episode 440, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.11019
# Episode 441, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.10964
# Episode 442, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.10909
# Episode 443, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.10855
# Episode 444, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.10801
# Episode 445, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.10747
# Episode 446, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.10693
# Episode 447, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.10639
# Episode 448, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.10586
# Episode 449, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.10533
# Episode 450, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.10481
# Episode 451, Total Reward: 134, Attempts: 6, Success: False, Epsilon: 0.10428
# Episode 452, Total Reward: 264, Attempts: 6, Success: True, Epsilon: 0.10376
# Episode 453, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.10324
# Episode 454, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.10273
# Episode 455, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.10221
# Episode 456, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.10170
# Episode 457, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.10119
# Episode 458, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.10069
# Episode 459, Total Reward: 104, Attempts: 6, Success: False, Epsilon: 0.10018
# Episode 460, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.09968
# Episode 461, Total Reward: 279, Attempts: 6, Success: True, Epsilon: 0.09918
# Episode 462, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.09869
# Episode 463, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.09819
# Episode 464, Total Reward: 153, Attempts: 2, Success: True, Epsilon: 0.09770
# Episode 465, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.09721
# Episode 466, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.09673
# Episode 467, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.09625
# Episode 468, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.09576
# Episode 469, Total Reward: 180, Attempts: 5, Success: True, Epsilon: 0.09529
# Episode 470, Total Reward: 157, Attempts: 3, Success: True, Epsilon: 0.09481
# Episode 471, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.09433
# Episode 472, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.09386
# Episode 473, Total Reward: 244, Attempts: 6, Success: True, Epsilon: 0.09339
# Episode 474, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.09293
# Episode 475, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.09246
# Episode 476, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.09200
# Episode 477, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.09154
# Episode 478, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.09108
# Episode 479, Total Reward: 254, Attempts: 6, Success: True, Epsilon: 0.09063
# Episode 480, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.09017
# Episode 481, Total Reward: 99, Attempts: 6, Success: False, Epsilon: 0.08972
# Episode 482, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.08927
# Episode 483, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.08883
# Episode 484, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.08838
# Episode 485, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.08794
# Episode 486, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.08750
# Episode 487, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.08706
# Episode 488, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.08663
# Episode 489, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.08620
# Episode 490, Total Reward: 202, Attempts: 3, Success: True, Epsilon: 0.08576
# Episode 491, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.08534
# Episode 492, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.08491
# Episode 493, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.08448
# Episode 494, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.08406
# Episode 495, Total Reward: 89, Attempts: 6, Success: False, Epsilon: 0.08364
# Episode 496, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.08322
# Episode 497, Total Reward: 190, Attempts: 5, Success: True, Epsilon: 0.08281
# Episode 498, Total Reward: 158, Attempts: 2, Success: True, Epsilon: 0.08239
# Episode 499, Total Reward: 157, Attempts: 3, Success: True, Epsilon: 0.08198
# Episode 500, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.08157
# Episode 501, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.08116
# Episode 502, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.08076
# Episode 503, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.08035
# Episode 504, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.07995
# Episode 505, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.07955
# Episode 506, Total Reward: 200, Attempts: 5, Success: True, Epsilon: 0.07916
# Episode 507, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.07876
# Episode 508, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.07837
# Episode 509, Total Reward: 224, Attempts: 6, Success: True, Epsilon: 0.07797
# Episode 510, Total Reward: 168, Attempts: 2, Success: True, Epsilon: 0.07758
# Episode 511, Total Reward: 207, Attempts: 3, Success: True, Epsilon: 0.07720
# Episode 512, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.07681
# Episode 513, Total Reward: 207, Attempts: 3, Success: True, Epsilon: 0.07643
# Episode 514, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.07604
# Episode 515, Total Reward: 74, Attempts: 6, Success: False, Epsilon: 0.07566
# Episode 516, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.07529
# Episode 517, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.07491
# Episode 518, Total Reward: 250, Attempts: 5, Success: True, Epsilon: 0.07453
# Episode 519, Total Reward: 235, Attempts: 5, Success: True, Epsilon: 0.07416
# Episode 520, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.07379
# Episode 521, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.07342
# Episode 522, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.07305
# Episode 523, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.07269
# Episode 524, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.07233
# Episode 525, Total Reward: 89, Attempts: 6, Success: False, Epsilon: 0.07196
# Episode 526, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.07160
# Episode 527, Total Reward: 250, Attempts: 5, Success: True, Epsilon: 0.07125
# Episode 528, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.07089
# Episode 529, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.07054
# Episode 530, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.07018
# Episode 531, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.06983
# Episode 532, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.06948
# Episode 533, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.06914
# Episode 534, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.06879
# Episode 535, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.06845
# Episode 536, Total Reward: 299, Attempts: 6, Success: True, Epsilon: 0.06810
# Episode 537, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.06776
# Episode 538, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.06742
# Episode 539, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.06709
# Episode 540, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.06675
# Episode 541, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.06642
# Episode 542, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.06609
# Episode 543, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.06576
# Episode 544, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.06543
# Episode 545, Total Reward: 239, Attempts: 6, Success: True, Epsilon: 0.06510
# Episode 546, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.06477
# Episode 547, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.06445
# Episode 548, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.06413
# Episode 549, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.06381
# Episode 550, Total Reward: 89, Attempts: 6, Success: False, Epsilon: 0.06349
# Episode 551, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.06317
# Episode 552, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.06286
# Episode 553, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.06254
# Episode 554, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.06223
# Episode 555, Total Reward: 168, Attempts: 2, Success: True, Epsilon: 0.06192
# Episode 556, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.06161
# Episode 557, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.06130
# Episode 558, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.06099
# Episode 559, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.06069
# Episode 560, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.06038
# Episode 561, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.06008
# Episode 562, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.05978
# Episode 563, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.05948
# Episode 564, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.05919
# Episode 565, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.05889
# Episode 566, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.05860
# Episode 567, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.05830
# Episode 568, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.05801
# Episode 569, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.05772
# Episode 570, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.05743
# Episode 571, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.05715
# Episode 572, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.05686
# Episode 573, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.05658
# Episode 574, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.05629
# Episode 575, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.05601
# Episode 576, Total Reward: 161, Attempts: 4, Success: True, Epsilon: 0.05573
# Episode 577, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.05545
# Episode 578, Total Reward: 200, Attempts: 5, Success: True, Epsilon: 0.05517
# Episode 579, Total Reward: 158, Attempts: 2, Success: True, Epsilon: 0.05490
# Episode 580, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.05462
# Episode 581, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.05435
# Episode 582, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.05408
# Episode 583, Total Reward: 185, Attempts: 5, Success: True, Epsilon: 0.05381
# Episode 584, Total Reward: 64, Attempts: 6, Success: False, Epsilon: 0.05354
# Episode 585, Total Reward: 200, Attempts: 5, Success: True, Epsilon: 0.05327
# Episode 586, Total Reward: 205, Attempts: 5, Success: True, Epsilon: 0.05301
# Episode 587, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.05274
# Episode 588, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.05248
# Episode 589, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.05221
# Episode 590, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.05195
# Episode 591, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.05169
# Episode 592, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.05144
# Episode 593, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.05118
# Episode 594, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.05092
# Episode 595, Total Reward: 259, Attempts: 6, Success: True, Epsilon: 0.05067
# Episode 596, Total Reward: 161, Attempts: 4, Success: True, Epsilon: 0.05041
# Episode 597, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.05016
# Episode 598, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.04991
# Episode 599, Total Reward: 231, Attempts: 4, Success: True, Epsilon: 0.04966
# Episode 600, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.04941
# Episode 601, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.04917
# Episode 602, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.04892
# Episode 603, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.04868
# Episode 604, Total Reward: 195, Attempts: 5, Success: True, Epsilon: 0.04843
# Episode 605, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.04819
# Episode 606, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.04795
# Episode 607, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.04771
# Episode 608, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.04747
# Episode 609, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.04723
# Episode 610, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.04700
# Episode 611, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.04676
# Episode 612, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.04653
# Episode 613, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.04630
# Episode 614, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.04607
# Episode 615, Total Reward: 254, Attempts: 6, Success: True, Epsilon: 0.04583
# Episode 616, Total Reward: 202, Attempts: 3, Success: True, Epsilon: 0.04561
# Episode 617, Total Reward: 249, Attempts: 6, Success: True, Epsilon: 0.04538
# Episode 618, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.04515
# Episode 619, Total Reward: 154, Attempts: 6, Success: False, Epsilon: 0.04492
# Episode 620, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.04470
# Episode 621, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.04448
# Episode 622, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.04425
# Episode 623, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.04403
# Episode 624, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.04381
# ...
# Episode 794, Total Reward: 195, Attempts: 5, Success: True, Epsilon: 0.01869
# Episode 795, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.01859
# Episode 796, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01850
# Episode 797, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01841
# Episode 798, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.01832
# Episode 799, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.01822
# Episode 800, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01813
# Episode 801, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.01804
# Episode 802, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01795
# Episode 803, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.01786
# Episode 804, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01777
# Episode 805, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01768
# Episode 806, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.01760
# Episode 807, Total Reward: 205, Attempts: 5, Success: True, Epsilon: 0.01751
# Episode 808, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01742
# Episode 809, Total Reward: 195, Attempts: 5, Success: True, Epsilon: 0.01733
# Episode 810, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.01725
# Episode 811, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01716
# Episode 812, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.01707
# Episode 813, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.01699
# Episode 814, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01690
# Episode 815, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01682
# Episode 816, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.01674
# Episode 817, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01665
# Episode 818, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.01657
# Episode 819, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.01649
# Episode 820, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.01640
# Episode 821, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.01632
# Episode 822, Total Reward: 259, Attempts: 6, Success: True, Epsilon: 0.01624
# Episode 823, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.01616
# Episode 824, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.01608
# Episode 825, Total Reward: 134, Attempts: 6, Success: False, Epsilon: 0.01600
# Episode 826, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.01592
# Episode 827, Total Reward: 200, Attempts: 5, Success: True, Epsilon: 0.01584
# Episode 828, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.01576
# Episode 829, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01568
# Episode 830, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01560
# Episode 831, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.01552
# Episode 832, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01545
# Episode 833, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01537
# Episode 834, Total Reward: 205, Attempts: 5, Success: True, Epsilon: 0.01529
# Episode 835, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.01522
# Episode 836, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.01514
# Episode 837, Total Reward: 259, Attempts: 6, Success: True, Epsilon: 0.01506
# Episode 838, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01499
# Episode 839, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01491
# Episode 840, Total Reward: 161, Attempts: 4, Success: True, Epsilon: 0.01484
# Episode 841, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.01476
# Episode 842, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01469
# Episode 843, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01462
# Episode 844, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.01454
# Episode 845, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01447
# Episode 846, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01440
# Episode 847, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.01433
# Episode 848, Total Reward: 239, Attempts: 6, Success: True, Epsilon: 0.01426
# Episode 849, Total Reward: 169, Attempts: 6, Success: False, Epsilon: 0.01418
# Episode 850, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.01411
# Episode 851, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.01404
# Episode 852, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01397
# Episode 853, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01390
# Episode 854, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.01383
# Episode 855, Total Reward: 129, Attempts: 6, Success: False, Epsilon: 0.01376
# Episode 856, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.01369
# Episode 857, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.01363
# Episode 858, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.01356
# Episode 859, Total Reward: 159, Attempts: 6, Success: False, Epsilon: 0.01349
# Episode 860, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01342
# Episode 861, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.01336
# Episode 862, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01329
# Episode 863, Total Reward: 236, Attempts: 4, Success: True, Epsilon: 0.01322
# Episode 864, Total Reward: 170, Attempts: 5, Success: True, Epsilon: 0.01316
# Episode 865, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.01309
# Episode 866, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01303
# Episode 867, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.01296
# Episode 868, Total Reward: 210, Attempts: 5, Success: True, Epsilon: 0.01290
# Episode 869, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.01283
# Episode 870, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.01277
# Episode 871, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01270
# Episode 872, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.01264
# Episode 873, Total Reward: 159, Attempts: 6, Success: False, Epsilon: 0.01258
# Episode 874, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.01251
# Episode 875, Total Reward: 187, Attempts: 3, Success: True, Epsilon: 0.01245
# Episode 876, Total Reward: 225, Attempts: 5, Success: True, Epsilon: 0.01239
# Episode 877, Total Reward: 192, Attempts: 3, Success: True, Epsilon: 0.01233
# Episode 878, Total Reward: 245, Attempts: 5, Success: True, Epsilon: 0.01226
# Episode 879, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01220
# Episode 880, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01214
# Episode 881, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01208
# Episode 882, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.01202
# Episode 883, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01196
# Episode 884, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01190
# Episode 885, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01184
# Episode 886, Total Reward: 254, Attempts: 6, Success: True, Epsilon: 0.01178
# Episode 887, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.01172
# Episode 888, Total Reward: 234, Attempts: 6, Success: True, Epsilon: 0.01167
# Episode 889, Total Reward: 195, Attempts: 5, Success: True, Epsilon: 0.01161
# Episode 890, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.01155
# Episode 891, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.01149
# Episode 892, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.01143
# Episode 893, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01138
# Episode 894, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01132
# Episode 895, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.01126
# Episode 896, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01121
# Episode 897, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01115
# Episode 898, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01109
# Episode 899, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.01104
# Episode 900, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.01098
# Episode 901, Total Reward: 124, Attempts: 6, Success: False, Epsilon: 0.01093
# Episode 902, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01087
# Episode 903, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01082
# Episode 904, Total Reward: 205, Attempts: 5, Success: True, Epsilon: 0.01077
# Episode 905, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01071
# Episode 906, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01066
# Episode 907, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.01061
# Episode 908, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.01055
# Episode 909, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01050
# Episode 910, Total Reward: 245, Attempts: 5, Success: True, Epsilon: 0.01045
# Episode 911, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01040
# Episode 912, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.01034
# Episode 913, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01029
# Episode 914, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.01024
# Episode 915, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.01019
# Episode 916, Total Reward: 304, Attempts: 6, Success: True, Epsilon: 0.01014
# Episode 917, Total Reward: 265, Attempts: 5, Success: True, Epsilon: 0.01009
# Episode 918, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.01004
# Episode 919, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 920, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 921, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 922, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 923, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 924, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 925, Total Reward: 211, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 926, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 927, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 928, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 929, Total Reward: 171, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 930, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 931, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 932, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 933, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 934, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 935, Total Reward: 202, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 936, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 937, Total Reward: 240, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 938, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 939, Total Reward: 304, Attempts: 6, Success: True, Epsilon: 0.01000
# Episode 940, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 941, Total Reward: 230, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 942, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 943, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 944, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 945, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 946, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 947, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 948, Total Reward: 161, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 949, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 950, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 951, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 952, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 953, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 954, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 955, Total Reward: 235, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 956, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 957, Total Reward: 240, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 958, Total Reward: 177, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 959, Total Reward: 124, Attempts: 6, Success: False, Epsilon: 0.01000
# Episode 960, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 961, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 962, Total Reward: 234, Attempts: 6, Success: True, Epsilon: 0.01000
# Episode 963, Total Reward: 167, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 964, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 965, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 966, Total Reward: 245, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 967, Total Reward: 221, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 968, Total Reward: 201, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 969, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 970, Total Reward: 162, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 971, Total Reward: 264, Attempts: 6, Success: True, Epsilon: 0.01000
# Episode 972, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 973, Total Reward: 196, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 974, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 975, Total Reward: 182, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 976, Total Reward: 216, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 977, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 978, Total Reward: 186, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 979, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 980, Total Reward: 235, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 981, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 982, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 983, Total Reward: 168, Attempts: 2, Success: True, Epsilon: 0.01000
# Episode 984, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 985, Total Reward: 215, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 986, Total Reward: 166, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 987, Total Reward: 224, Attempts: 6, Success: True, Epsilon: 0.01000
# Episode 988, Total Reward: 170, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 989, Total Reward: 191, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 990, Total Reward: 220, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 991, Total Reward: 176, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 992, Total Reward: 254, Attempts: 6, Success: True, Epsilon: 0.01000
# Episode 993, Total Reward: 206, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 994, Total Reward: 172, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 995, Total Reward: 181, Attempts: 4, Success: True, Epsilon: 0.01000
# Episode 996, Total Reward: 185, Attempts: 5, Success: True, Epsilon: 0.01000
# Episode 997, Total Reward: 197, Attempts: 3, Success: True, Epsilon: 0.01000
# Episode 998, Total Reward: 163, Attempts: 2, Success: True, Epsilon: 0.01000
# Episode 999, Total Reward: 153, Attempts: 2, Success: True, Epsilon: 0.01000
# Episode 1000, Total Reward: 234, Attempts: 6, Success: True, Epsilon: 0.01000

# %%
# I used this to run tests, to determine what I can change for it to run better. And to understand how the rewards are calculated. This helped me improve the model a lot.
num_tests = 10

for test in range(num_tests):
    env = WordletwoEnv(word_list)
    state = env.reset()
    total_reward = 0  # Track total reward per episode
    print(f"\nTest Episode {test + 1}: Target word is '{env.target_word.upper()}' (Hidden from RL)")

    done = False
    attempt = 1  # Track attempt number

    while not done:
        action = random.randint(0, len(env.word_list) - 1)
        state, reward, done, info = env.test_step(action)
        total_reward += reward  # Accumulate total reward

        # Print reward for this attempt
        print(f"Attempt {attempt}: Reward = {reward}, Total Reward = {total_reward}")
        attempt += 1

    print(f"Test Episode {test + 1} completed. Total Reward: {total_reward}\n")
# Out:
# Test Episode 1: Target word is 'WELSH' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ 🟨 ⬜ ⬜
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CHEST
# Feedback: ⬜ 🟨 🟨 🟩 ⬜
# Attempt 2: Reward = 9, Total Reward = 11
# Attempt 3: WELSH
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 3 attempts! 🎉
# Attempt 3: Reward = 125, Total Reward = 136
# Test Episode 1 completed. Total Reward: 136
#
#
# Test Episode 2: Target word is 'CABIN' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 🟨 ⬜ ⬜ ⬜
# Attempt 1: Reward = 4, Total Reward = 4
# Attempt 2: BADGE
# Feedback: 🟨 🟩 ⬜ ⬜ ⬜
# Attempt 2: Reward = 7, Total Reward = 11
# Attempt 3: CABIN
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 3 attempts! 🎉
# Attempt 3: Reward = 125, Total Reward = 136
# Test Episode 2 completed. Total Reward: 136
#
#
# Test Episode 3: Target word is 'THONG' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ 🟨 🟨 ⬜
# Attempt 1: Reward = 4, Total Reward = 4
# Attempt 2: CHOKE
# Feedback: ⬜ 🟩 🟩 ⬜ ⬜
# Attempt 2: Reward = 10, Total Reward = 14
# Attempt 3: GHOST
# Feedback: 🟨 🟩 🟩 ⬜ 🟨
# Attempt 3: Reward = 14, Total Reward = 28
# Attempt 4: THONG
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 153
# Test Episode 3 completed. Total Reward: 153
#
#
# Test Episode 4: Target word is 'ITCHY' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ 🟨 ⬜ ⬜
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CHEST
# Feedback: 🟨 🟨 ⬜ ⬜ 🟨
# Attempt 2: Reward = 6, Total Reward = 8
# Attempt 3: DITCH
# Feedback: ⬜ 🟨 🟨 🟨 🟨
# Attempt 3: Reward = 8, Total Reward = 16
# Attempt 4: ITCHY
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 141
# Test Episode 4 completed. Total Reward: 141
#
#
# Test Episode 5: Target word is 'SCOUR' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ 🟨 🟩
# Attempt 1: Reward = 7, Total Reward = 7
# Attempt 2: COVER
# Feedback: 🟨 🟨 ⬜ ⬜ 🟩
# Attempt 2: Reward = 9, Total Reward = 16
# Attempt 3: SCOUR
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 3 attempts! 🎉
# Attempt 3: Reward = 125, Total Reward = 141
# Test Episode 5 completed. Total Reward: 141
#
#
# Test Episode 6: Target word is 'UNION' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ 🟩 ⬜
# Attempt 1: Reward = 5, Total Reward = 5
# Attempt 2: DECOY
# Feedback: ⬜ ⬜ ⬜ 🟩 ⬜
# Attempt 2: Reward = 5, Total Reward = 10
# Attempt 3: INGOT
# Feedback: 🟨 🟩 ⬜ 🟩 ⬜
# Attempt 3: Reward = 12, Total Reward = 22
# Attempt 4: UNION
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 147
# Test Episode 6 completed. Total Reward: 147
#
#
# Test Episode 7: Target word is 'GRIME' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ ⬜ 🟨
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CLERK
# Feedback: ⬜ ⬜ 🟨 🟨 ⬜
# Attempt 2: Reward = 4, Total Reward = 6
# Attempt 3: DIRGE
# Feedback: ⬜ 🟨 🟨 🟨 🟩
# Attempt 3: Reward = 11, Total Reward = 17
# Attempt 4: GRIME
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 142
# Test Episode 7 completed. Total Reward: 142
#
#
# Test Episode 8: Target word is 'SLANT' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 ⬜ ⬜ ⬜ ⬜
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CADET
# Feedback: ⬜ 🟨 ⬜ ⬜ 🟩
# Attempt 2: Reward = 7, Total Reward = 9
# Attempt 3: GIANT
# Feedback: ⬜ ⬜ 🟩 🟩 🟩
# Attempt 3: Reward = 15, Total Reward = 24
# Attempt 4: PLANT
# Feedback: ⬜ 🟩 🟩 🟩 🟩
# Attempt 4: Reward = 20, Total Reward = 44
# Attempt 5: SLANT
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 5 attempts! 🎉
# Attempt 5: Reward = 125, Total Reward = 169
# Test Episode 8 completed. Total Reward: 169
#
#
# Test Episode 9: Target word is 'AMASS' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟩 ⬜ ⬜ ⬜ ⬜
# Attempt 1: Reward = 5, Total Reward = 5
# Attempt 2: ACUTE
# Feedback: 🟩 ⬜ ⬜ ⬜ ⬜
# Attempt 2: Reward = 5, Total Reward = 10
# Attempt 3: ADMIN
# Feedback: 🟩 ⬜ 🟨 ⬜ ⬜
# Attempt 3: Reward = 7, Total Reward = 17
# Attempt 4: AMPLY
# Feedback: 🟩 🟩 ⬜ ⬜ ⬜
# Attempt 4: Reward = 10, Total Reward = 27
# Attempt 5: AMASS
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 5 attempts! 🎉
# Attempt 5: Reward = 125, Total Reward = 152
# Test Episode 9 completed. Total Reward: 152
#
#
# Test Episode 10: Target word is 'GIANT' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 ⬜ ⬜ ⬜ ⬜
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CADET
# Feedback: ⬜ 🟨 ⬜ ⬜ 🟩
# Attempt 2: Reward = 7, Total Reward = 9
# Attempt 3: GIANT
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 3 attempts! 🎉
# Attempt 3: Reward = 125, Total Reward = 134
# Test Episode 10 completed. Total Reward: 134

# %%
#Here I tried to find the worst games (least rewards) so I can try to improve them, but it did not really work. 
import random

num_tests = 20  # Increase test episodes to 20
reward_threshold = 100  # Maximum allowed reward per episode
max_attempts = 6  # Ensure all 6 attempts are visible per episode

for test in range(num_tests):
    env = WordletwoEnv(word_list)
    state = env.reset()
    total_reward = 0  # Track total reward per episode
    print(f"\nTest Episode {test + 1}: Target word is '{env.target_word.upper()}' (Hidden from RL)")
    
    done = False
    attempt = 1  # Track attempt number
    
    while not done and attempt <= max_attempts:
        action = random.randint(0, len(env.word_list) - 1)
        state, reward, done, info = env.test_step(action)
        total_reward += reward  # Accumulate total reward
        
        # Print reward for this attempt
        print(f"Attempt {attempt}: Reward = {reward}, Total Reward = {total_reward}")
        attempt += 1
        
    # Ensure total reward stays below the threshold and all 6 attempts are shown
    if total_reward <= reward_threshold:
        print(f"Total reward exceeded {reward_threshold}. Restarting episode...\n")
        total_reward = 0
        state = env.reset()
        attempt = 1
        continue
    
    print(f"Test Episode {test + 1} completed. Total Reward: {total_reward}\n")
# Out:
# Test Episode 1: Target word is 'TERSE' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ ⬜ 🟨
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CLERK
# Feedback: ⬜ ⬜ 🟨 🟨 ⬜
# Attempt 2: Reward = 4, Total Reward = 6
# Attempt 3: DIRGE
# Feedback: ⬜ ⬜ 🟩 ⬜ 🟩
# Attempt 3: Reward = 10, Total Reward = 16
# Attempt 4: NURSE
# Feedback: ⬜ ⬜ 🟩 🟩 🟩
# Attempt 4: Reward = 15, Total Reward = 31
# Attempt 5: TERSE
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 5 attempts! 🎉
# Attempt 5: Reward = 125, Total Reward = 156
# Test Episode 1 completed. Total Reward: 156
#
#
# Test Episode 2: Target word is 'PUPAL' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 ⬜ ⬜ ⬜ ⬜
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CADET
# Feedback: ⬜ 🟨 ⬜ ⬜ ⬜
# Attempt 2: Reward = 2, Total Reward = 4
# Attempt 3: FINAL
# Feedback: ⬜ ⬜ ⬜ 🟩 🟩
# Attempt 3: Reward = 10, Total Reward = 14
# Attempt 4: PUPAL
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 139
# Test Episode 2 completed. Total Reward: 139
#
#
# Test Episode 3: Target word is 'RETCH' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ 🟨 ⬜ 🟨
# Attempt 1: Reward = 4, Total Reward = 4
# Attempt 2: CHIRP
# Feedback: 🟨 🟨 ⬜ 🟨 ⬜
# Attempt 2: Reward = 6, Total Reward = 10
# Attempt 3: LURCH
# Feedback: ⬜ ⬜ 🟨 🟩 🟩
# Attempt 3: Reward = 12, Total Reward = 22
# Attempt 4: RETCH
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 147
# Test Episode 3 completed. Total Reward: 147
#
#
# Test Episode 4: Target word is 'NOBLY' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ 🟨 ⬜ 🟨 ⬜
# Attempt 1: Reward = 4, Total Reward = 4
# Attempt 2: BINGO
# Feedback: 🟨 ⬜ 🟨 ⬜ 🟨
# Attempt 2: Reward = 6, Total Reward = 10
# Attempt 3: NOBLE
# Feedback: 🟩 🟩 🟩 🟩 ⬜
# Attempt 3: Reward = 20, Total Reward = 30
# Attempt 4: NOBLY
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 155
# Test Episode 4 completed. Total Reward: 155
#
#
# Test Episode 5: Target word is 'AWOKE' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟩 ⬜ ⬜ 🟨 ⬜
# Attempt 1: Reward = 7, Total Reward = 7
# Attempt 2: ADOPT
# Feedback: 🟩 ⬜ 🟩 ⬜ ⬜
# Attempt 2: Reward = 10, Total Reward = 17
# Attempt 3: AFOUL
# Feedback: 🟩 ⬜ 🟩 ⬜ ⬜
# Attempt 3: Reward = 10, Total Reward = 27
# Attempt 4: AGONY
# Feedback: 🟩 ⬜ 🟩 ⬜ ⬜
# Attempt 4: Reward = 10, Total Reward = 37
# Attempt 5: AWOKE
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 5 attempts! 🎉
# Attempt 5: Reward = 125, Total Reward = 162
# Test Episode 5 completed. Total Reward: 162
#
#
# Test Episode 6: Target word is 'LUSTY' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ ⬜ ⬜
# Attempt 1: Reward = 0, Total Reward = 0
# Attempt 2: CLEFT
# Feedback: ⬜ 🟨 ⬜ ⬜ 🟨
# Attempt 2: Reward = 4, Total Reward = 4
# Attempt 3: LUSTY
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 3 attempts! 🎉
# Attempt 3: Reward = 125, Total Reward = 129
# Test Episode 6 completed. Total Reward: 129
#
#
# Test Episode 7: Target word is 'PEACH' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 ⬜ 🟨 ⬜ ⬜
# Attempt 1: Reward = 4, Total Reward = 4
# Attempt 2: CHAFE
# Feedback: 🟨 🟨 🟩 ⬜ 🟨
# Attempt 2: Reward = 11, Total Reward = 15
# Attempt 3: LEACH
# Feedback: ⬜ 🟩 🟩 🟩 🟩
# Attempt 3: Reward = 20, Total Reward = 35
# Attempt 4: PEACH
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 160
# Test Episode 7 completed. Total Reward: 160
#
#
# Test Episode 8: Target word is 'DRAWL' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 ⬜ ⬜ ⬜ 🟨
# Attempt 1: Reward = 4, Total Reward = 4
# Attempt 2: CAIRN
# Feedback: ⬜ 🟨 ⬜ 🟨 ⬜
# Attempt 2: Reward = 4, Total Reward = 8
# Attempt 3: DRAFT
# Feedback: 🟩 🟩 🟩 ⬜ ⬜
# Attempt 3: Reward = 15, Total Reward = 23
# Attempt 4: DRAKE
# Feedback: 🟩 🟩 🟩 ⬜ ⬜
# Attempt 4: Reward = 15, Total Reward = 38
# Attempt 5: DRAWL
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 5 attempts! 🎉
# Attempt 5: Reward = 125, Total Reward = 163
# Test Episode 8 completed. Total Reward: 163
#
#
# Test Episode 9: Target word is 'ROBIN' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ 🟨 ⬜ 🟨 🟨
# Attempt 1: Reward = 6, Total Reward = 6
# Attempt 2: BORNE
# Feedback: 🟨 🟩 🟨 🟨 ⬜
# Attempt 2: Reward = 11, Total Reward = 17
# Attempt 3: ROBIN
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 3 attempts! 🎉
# Attempt 3: Reward = 125, Total Reward = 142
# Test Episode 9 completed. Total Reward: 142
#
#
# Test Episode 10: Target word is 'BAWDY' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 🟨 ⬜ ⬜ ⬜
# Attempt 1: Reward = 4, Total Reward = 4
# Attempt 2: BADGE
# Feedback: 🟩 🟩 🟨 ⬜ ⬜
# Attempt 2: Reward = 12, Total Reward = 16
# Attempt 3: BAWDY
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 3 attempts! 🎉
# Attempt 3: Reward = 125, Total Reward = 141
# Test Episode 10 completed. Total Reward: 141
#
#
# Test Episode 11: Target word is 'FLOOR' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ 🟩 🟩
# Attempt 1: Reward = 10, Total Reward = 10
# Attempt 2: DECOR
# Feedback: ⬜ ⬜ ⬜ 🟩 🟩
# Attempt 2: Reward = 10, Total Reward = 20
# Attempt 3: MINOR
# Feedback: ⬜ ⬜ ⬜ 🟩 🟩
# Attempt 3: Reward = 10, Total Reward = 30
# Attempt 4: FLOOR
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 155
# Test Episode 11 completed. Total Reward: 155
#
#
# Test Episode 12: Target word is 'GREED' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ ⬜ 🟨
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CLERK
# Feedback: ⬜ ⬜ 🟩 🟨 ⬜
# Attempt 2: Reward = 7, Total Reward = 9
# Attempt 3: TREND
# Feedback: ⬜ 🟩 🟩 ⬜ 🟩
# Attempt 3: Reward = 15, Total Reward = 24
# Attempt 4: FREED
# Feedback: ⬜ 🟩 🟩 🟩 🟩
# Attempt 4: Reward = 20, Total Reward = 44
# Attempt 5: GREED
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 5 attempts! 🎉
# Attempt 5: Reward = 125, Total Reward = 169
# Test Episode 12 completed. Total Reward: 169
#
#
# Test Episode 13: Target word is 'OUTGO' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ 🟨 ⬜
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CLONE
# Feedback: ⬜ ⬜ 🟨 ⬜ ⬜
# Attempt 2: Reward = 2, Total Reward = 4
# Attempt 3: FOIST
# Feedback: ⬜ 🟨 ⬜ ⬜ 🟨
# Attempt 3: Reward = 4, Total Reward = 8
# Attempt 4: OUTDO
# Feedback: 🟩 🟩 🟩 ⬜ 🟩
# Attempt 4: Reward = 20, Total Reward = 28
# Attempt 5: OUTGO
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 5 attempts! 🎉
# Attempt 5: Reward = 125, Total Reward = 153
# Test Episode 13 completed. Total Reward: 153
#
#
# Test Episode 14: Target word is 'NUTTY' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ ⬜ ⬜
# Attempt 1: Reward = 0, Total Reward = 0
# Attempt 2: CLEFT
# Feedback: ⬜ ⬜ ⬜ ⬜ 🟨
# Attempt 2: Reward = 2, Total Reward = 2
# Attempt 3: DUSTY
# Feedback: ⬜ 🟩 ⬜ 🟩 🟩
# Attempt 3: Reward = 15, Total Reward = 17
# Attempt 4: NUTTY
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 142
# Test Episode 14 completed. Total Reward: 142
#
#
# Test Episode 15: Target word is 'BIRTH' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ 🟨 🟨 ⬜ 🟨
# Attempt 1: Reward = 6, Total Reward = 6
# Attempt 2: BERTH
# Feedback: 🟩 ⬜ 🟩 🟩 🟩
# Attempt 2: Reward = 20, Total Reward = 26
# Attempt 3: BIRTH
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 3 attempts! 🎉
# Attempt 3: Reward = 125, Total Reward = 151
# Test Episode 15 completed. Total Reward: 151
#
#
# Test Episode 16: Target word is 'BLEAK' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 🟨 ⬜ ⬜ ⬜
# Attempt 1: Reward = 4, Total Reward = 4
# Attempt 2: BADGE
# Feedback: 🟩 🟨 ⬜ ⬜ 🟨
# Attempt 2: Reward = 9, Total Reward = 13
# Attempt 3: BEAST
# Feedback: 🟩 🟨 🟨 ⬜ ⬜
# Attempt 3: Reward = 9, Total Reward = 22
# Attempt 4: BLEAK
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 147
# Test Episode 16 completed. Total Reward: 147
#
#
# Test Episode 17: Target word is 'LEACH' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 ⬜ 🟨 ⬜ ⬜
# Attempt 1: Reward = 4, Total Reward = 4
# Attempt 2: CHAFE
# Feedback: 🟨 🟨 🟩 ⬜ 🟨
# Attempt 2: Reward = 11, Total Reward = 15
# Attempt 3: LEACH
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 3 attempts! 🎉
# Attempt 3: Reward = 125, Total Reward = 140
# Test Episode 17 completed. Total Reward: 140
#
#
# Test Episode 18: Target word is 'SAVVY' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: 🟨 ⬜ ⬜ ⬜ ⬜
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CADET
# Feedback: ⬜ 🟩 ⬜ ⬜ ⬜
# Attempt 2: Reward = 5, Total Reward = 7
# Attempt 3: GAILY
# Feedback: ⬜ 🟩 ⬜ ⬜ 🟩
# Attempt 3: Reward = 10, Total Reward = 17
# Attempt 4: PANSY
# Feedback: ⬜ 🟩 ⬜ 🟨 🟩
# Attempt 4: Reward = 12, Total Reward = 29
# Attempt 5: SAVVY
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 5 attempts! 🎉
# Attempt 5: Reward = 125, Total Reward = 154
# Test Episode 18 completed. Total Reward: 154
#
#
# Test Episode 19: Target word is 'POSIT' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ 🟨 ⬜
# Attempt 1: Reward = 2, Total Reward = 2
# Attempt 2: CLONE
# Feedback: ⬜ ⬜ 🟨 ⬜ ⬜
# Attempt 2: Reward = 2, Total Reward = 4
# Attempt 3: FOIST
# Feedback: ⬜ 🟩 🟨 🟨 🟩
# Attempt 3: Reward = 14, Total Reward = 18
# Attempt 4: POSIT
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 143
# Test Episode 19 completed. Total Reward: 143
#
#
# Test Episode 20: Target word is 'UNION' (Hidden from RL)
# Attempt 1: ABHOR
# Feedback: ⬜ ⬜ ⬜ 🟩 ⬜
# Attempt 1: Reward = 5, Total Reward = 5
# Attempt 2: DECOY
# Feedback: ⬜ ⬜ ⬜ 🟩 ⬜
# Attempt 2: Reward = 5, Total Reward = 10
# Attempt 3: INGOT
# Feedback: 🟨 🟩 ⬜ 🟩 ⬜
# Attempt 3: Reward = 12, Total Reward = 22
# Attempt 4: UNION
# Feedback: 🟩 🟩 🟩 🟩 🟩
# Correct word found in 4 attempts! 🎉
# Attempt 4: Reward = 125, Total Reward = 147
# Test Episode 20 completed. Total Reward: 147

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Load saved results
df_results = pd.read_csv("wordletwo_rl_results.csv")

# First I plot the total reward per episode
plt.figure(figsize=(10, 5))
plt.plot(df_results["Episode"], df_results["Total Reward"], label="Total Reward per Episode")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Total Reward Progression")
plt.legend()
plt.show()

# Second I plot epsilon decay
plt.figure(figsize=(10, 5))
plt.plot(df_results["Episode"], df_results["Epsilon"], label="Epsilon Decay", color="orange")
plt.xlabel("Episode")
plt.ylabel("Epsilon")
plt.title("Epsilon Decay Over Time")
plt.legend()
plt.show()

# Then third I plot number of attempts per episode
plt.figure(figsize=(10, 5))
plt.plot(df_results["Episode"], df_results["Attempts"], label="Attempts per Episode", color="green")
plt.xlabel("Episode")
plt.ylabel("Number of Attempts")
plt.title("Attempts Per Episode Over Time")
plt.legend()
plt.show()

# Last I plot success rate over episodes
plt.figure(figsize=(10, 5))
plt.plot(df_results["Episode"], df_results["Success"].cumsum() / (df_results["Episode"]), label="Success Rate Over Time", color="blue")
plt.xlabel("Episode")
plt.ylabel("Cumulative Success Rate")
plt.title("Success Rate Over Time")
plt.legend()
plt.show()

# %%
#Since the results are not amazing and the rewards remain almost the same I tried different plots

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter

# Load saved results
df_results = pd.read_csv("wordle_rl_results.csv")

# Define a smoothing function (Moving Average)
def moving_average(data, window_size=50):
    return data.rolling(window=window_size).mean()

# Apply moving average to total rewards
df_results["Smoothed Reward"] = moving_average(df_results["Total Reward"], window_size=50)

# Apply Savitzky-Golay filter for better smoothing
df_results["Smoothed Reward SG"] = savgol_filter(df_results["Total Reward"], window_length=51, polyorder=3)

# Plot total reward per episode with different smoothing techniques
plt.figure(figsize=(10, 5))
plt.plot(df_results["Episode"], df_results["Total Reward"], label="Raw Total Reward", alpha=0.3, color="gray")
plt.plot(df_results["Episode"], df_results["Smoothed Reward"], label="Moving Average (50 Episodes)", color="red")
plt.plot(df_results["Episode"], df_results["Smoothed Reward SG"], label="Savitzky-Golay Smoothed", color="blue")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Total Reward Progression with Smoothing")
plt.legend()
plt.show()

# Plot total reward with log scale
plt.figure(figsize=(10, 5))
plt.plot(df_results["Episode"], df_results["Total Reward"], label="Total Reward per Episode")
plt.yscale("log")
plt.xlabel("Episode")
plt.ylabel("Total Reward (log scale)")
plt.title("Total Reward Progression (Log Scale)")
plt.legend()
plt.show()

# Polynomial trend line (2nd order)
coeffs = np.polyfit(df_results["Episode"], df_results["Total Reward"], 2)
poly_trend = np.polyval(coeffs, df_results["Episode"])

plt.figure(figsize=(10, 5))
plt.plot(df_results["Episode"], df_results["Total Reward"], label="Raw Total Reward", alpha=0.3, color="gray")
plt.plot(df_results["Episode"], poly_trend, label="Polynomial Trend (2nd Order)", color="green")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Total Reward with PolynomialTrend")
plt.legend()
plt.show()

# %%
#Last resort was just printing this text. My program does not work properly. It only improved 2,81 over all. It does not get better the more it learns. I do not know what else to do.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter

# Load saved results
df_results = pd.read_csv("wordle_rl_results.csv")

print(f"Average reward in the first 100 episodes:  {first_100_avg:.2f}")
print(f"Average reward in the last 100 episodes:  {last_100_avg:.2f}")
print(f"Reward improvement: {last_100_avg - first_100_avg:.2f}")
# Out:
# Average reward in the first 100 episodes:  145.34
# Average reward in the last 100 episodes:  148.15
# Reward improvement: 2.81
